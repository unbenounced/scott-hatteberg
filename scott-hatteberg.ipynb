# %%
# !pip install pybaseball > null

# %%
from pybaseball import statcast_batter
from pybaseball import playerid_lookup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
pd.set_option('display.max_columns', 500)
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]

# %%
# find Scott Hatteberg's player id (mlbam_key)
mlbam = playerid_lookup('hatteberg', 'scott').loc[0, 'key_mlbam']

# get all available date
data = statcast_batter('2008-04-01', '2024-07-30', mlbam)
data
# Out:
# Gathering Player Data
# C:\Users\marti\anaconda3\Lib\site-packages\pybaseball\utils.py:299: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return pd.concat(results)
#     pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0           CH  2008-05-25           82.6          -2.93           6.37
# 1           SI  2008-05-25           93.0          -3.64           6.08
# 2           SI  2008-05-25           92.8          -3.72           6.05
# 3           SI  2008-05-25           92.7          -3.88           5.91
# 4           FF  2008-05-23           85.9          -1.33           6.63
# ..         ...         ...            ...            ...            ...
# 200         FF  2008-04-03           83.3           2.41           6.97
# 201        NaN  2008-04-03            NaN            NaN            NaN
# 202         CH  2008-04-03           77.1          -0.05           6.05
# 203         FF  2008-04-03           87.2           2.64           6.70
# 204         SI  2008-04-03           87.7           2.63           6.70
#
#           player_name  batter pitcher     events    description  spin_dir  \
# 0    Hatteberg, Scott  115608  132241  field_out  hit_into_play       NaN
# 1    Hatteberg, Scott  115608  132241        NaN           foul       NaN
# 2    Hatteberg, Scott  115608  132241        NaN  called_strike       NaN
# 3    Hatteberg, Scott  115608  132241        NaN           ball       NaN
# 4    Hatteberg, Scott  115608  116034  field_out  hit_into_play       NaN
# ..                ...     ...     ...        ...            ...       ...
# 200  Hatteberg, Scott  115608  150277        NaN  called_strike       NaN
# 201  Hatteberg, Scott  115608  433589  field_out  hit_into_play       NaN
# 202  Hatteberg, Scott  115608  433589        NaN           foul       NaN
# 203  Hatteberg, Scott  115608  460657  field_out  hit_into_play       NaN
# 204  Hatteberg, Scott  115608  460657        NaN           ball       NaN
#
#      spin_rate_deprecated  break_angle_deprecated  break_length_deprecated  \
# 0                     NaN                     NaN                      NaN
# 1                     NaN                     NaN                      NaN
# 2                     NaN                     NaN                      NaN
# 3                     NaN                     NaN                      NaN
# 4                     NaN                     NaN                      NaN
# ..                    ...                     ...                      ...
# 200                   NaN                     NaN                      NaN
# 201                   NaN                     NaN                      NaN
# 202                   NaN                     NaN                      NaN
# 203                   NaN                     NaN                      NaN
# 204                   NaN                     NaN                      NaN
#
#      zone                                                des game_type stand  \
# 0     8.0  Scott Hatteberg pops out to catcher Michael Ba...         R     L
# 1     8.0  Scott Hatteberg pops out to catcher Michael Ba...         R     L
# 2    13.0  Scott Hatteberg pops out to catcher Michael Ba...         R     L
# 3    11.0  Scott Hatteberg pops out to catcher Michael Ba...         R     L
# 4     4.0  Scott Hatteberg grounds out, second baseman Ta...         R     L
# ..    ...                                                ...       ...   ...
# 200   4.0  Scott Hatteberg reaches on a fielding error by...         R     L
# 201   NaN  Scott Hatteberg lines out to right fielder Jus...         R     L
# 202   4.0  Scott Hatteberg lines out to right fielder Jus...         R     L
# 203   2.0  Scott Hatteberg pops out to shortstop Stephen ...         R     L
# 204   9.0  Scott Hatteberg pops out to shortstop Stephen ...         R     L
#
#     p_throws home_team away_team type  hit_location      bb_type balls  \
# 0          R        SD       CIN    X           2.0        popup     1
# 1          R        SD       CIN    S           NaN          NaN     1
# 2          R        SD       CIN    S           NaN          NaN     1
# 3          R        SD       CIN    B           NaN          NaN     0
# 4          R        SD       CIN    X           4.0  ground_ball     1
# ..       ...       ...       ...  ...           ...          ...   ...
# 200        L       CIN        AZ    S           NaN          NaN     0
# 201        R       CIN        AZ    X           9.0   line_drive     0
# 202        R       CIN        AZ    S           NaN          NaN     0
# 203        L       CIN        AZ    X           6.0        popup     1
# 204        L       CIN        AZ    B           NaN          NaN     0
#
#     strikes game_year  pfx_x  pfx_z  plate_x  plate_z     on_3b     on_2b  \
# 0         2      2008  -1.20   1.23     0.10     1.99       NaN       NaN
# 1         1      2008  -1.20   0.95     0.10     1.98       NaN       NaN
# 2         0      2008  -1.41   1.19    -0.89     1.87       NaN       NaN
# 3         0      2008  -1.52   1.03    -1.44     3.32       NaN       NaN
# 4         0      2008  -0.34   2.36    -0.65     2.13       NaN       NaN
# ..      ...       ...    ...    ...      ...      ...       ...       ...
# 200       0      2008   1.07   1.78    -0.47     2.31  408252.0  276055.0
# 201       1      2008    NaN    NaN      NaN      NaN       NaN       NaN
# 202       0      2008   0.05   1.73    -0.56     2.21       NaN       NaN
# 203       0      2008   1.62   1.46    -0.04     2.91       NaN       NaN
# 204       0      2008   1.92   1.34     0.42     1.71       NaN       NaN
#
#         on_1b outs_when_up inning inning_topbot    hc_x    hc_y  \
# 0    424325.0            1      6           Top  118.47  210.84
# 1    424325.0            1      6           Top     NaN     NaN
# 2    424325.0            1      6           Top     NaN     NaN
# 3    424325.0            1      6           Top     NaN     NaN
# 4    458015.0            2      9           Top  143.57  152.61
# ..        ...          ...    ...           ...     ...     ...
# 200  429665.0            2      1           Bot     NaN     NaN
# 201       NaN            2      5           Bot  152.61  102.41
# 202       NaN            2      5           Bot     NaN     NaN
# 203       NaN            2      7           Bot  101.41  137.55
# 204       NaN            2      7           Bot     NaN     NaN
#
#      tfs_deprecated  tfs_zulu_deprecated fielder_2 umpire          sv_id  \
# 0               NaN                  NaN    136664    NaN  080525_145129
# 1               NaN                  NaN    136664    NaN  080525_145100
# 2               NaN                  NaN    136664    NaN  080525_145039
# 3               NaN                  NaN    136664    NaN  080525_145020
# 4               NaN                  NaN    450192    NaN  080523_223142
# ..              ...                  ...       ...    ...            ...
# 200             NaN                  NaN    425631    NaN  080403_125848
# 201             NaN                  NaN    425631    NaN            NaN
# 202             NaN                  NaN    425631    NaN  080403_140847
# 203             NaN                  NaN    425631    NaN  080403_144945
# 204             NaN                  NaN    425631    NaN  080403_144930
#
#            vx0         vy0       vz0      ax      ay      az  sz_top  sz_bot  \
# 0     9.633359 -120.911288 -4.867098 -13.438  28.737 -19.605    3.42    1.44
# 1    12.666443 -135.970873 -5.903571 -17.461  36.155 -19.446    3.42    1.44
# 2    10.863358 -135.827212 -6.749488 -19.338  34.062 -16.427    3.42    1.44
# 3    10.146860 -135.989735 -2.214551 -20.542  37.264 -19.567    3.42    1.44
# 4     2.429050 -125.951898 -8.619072  -4.069  32.343  -6.378    3.04    1.46
# ..         ...         ...       ...     ...     ...     ...     ...     ...
# 200  -9.048505 -121.514009 -7.112692  11.937  21.317 -13.735    3.04    1.46
# 201        NaN         NaN       NaN     NaN     NaN     NaN     NaN     NaN
# 202  -1.169150 -112.895728 -3.702109   0.579  17.251 -17.080    3.14    1.58
# 203 -10.318640 -127.371932 -5.332171  19.119  23.049 -15.654    3.14    1.58
# 204  -9.947701 -128.031848 -7.993921  22.391  24.947 -16.334    3.14    1.58
#
#      hit_distance_sc  launch_speed  launch_angle  effective_speed  \
# 0                NaN           NaN           NaN              NaN
# 1                NaN           NaN           NaN              NaN
# 2                NaN           NaN           NaN              NaN
# 3                NaN           NaN           NaN              NaN
# 4                NaN           NaN           NaN              NaN
# ..               ...           ...           ...              ...
# 200              NaN           NaN           NaN              NaN
# 201              NaN           NaN           NaN              NaN
# 202              NaN           NaN           NaN              NaN
# 203              NaN           NaN           NaN              NaN
# 204              NaN           NaN           NaN              NaN
#
#      release_spin_rate  release_extension game_pk pitcher.1 fielder_2.1  \
# 0                  NaN                NaN  234514    132241      136664
# 1                  NaN                NaN  234514    132241      136664
# 2                  NaN                NaN  234514    132241      136664
# 3                  NaN                NaN  234514    132241      136664
# 4                  NaN                NaN  234484    116034      450192
# ..                 ...                ...     ...       ...         ...
# 200                NaN                NaN  233796    150277      425631
# 201                NaN                NaN  233796    433589      425631
# 202                NaN                NaN  233796    433589      425631
# 203                NaN                NaN  233796    460657      425631
# 204                NaN                NaN  233796    460657      425631
#
#     fielder_3 fielder_4 fielder_5 fielder_6 fielder_7 fielder_8 fielder_9  \
# 0      408236    435338    450260    425867    434582    430668    114789
# 1      408236    435338    450260    425867    434582    430668    114789
# 2      408236    435338    450260    425867    434582    430668    114789
# 3      408236    435338    450260    425867    434582    430668    114789
# 4      408236    435338    450260    425867    430668    425506    114789
# ..        ...       ...       ...       ...       ...       ...       ...
# 200    429663    407861    448602    452220    291565    455759    457708
# 201    429663    407861    448602    452220    291565    455759    457708
# 202    429663    407861    448602    452220    291565    455759    457708
# 203    429663    407861    448602    452220    291565    455759    457708
# 204    429663    407861    448602    452220    291565    455759    457708
#
#      release_pos_y  estimated_ba_using_speedangle  \
# 0             54.5                            NaN
# 1             54.5                            NaN
# 2             54.5                            NaN
# 3             54.5                            NaN
# 4             54.5                            NaN
# ..             ...                            ...
# 200           54.5                            NaN
# 201            NaN                            NaN
# 202           54.5                            NaN
# 203           54.5                            NaN
# 204           54.5                            NaN
#
#      estimated_woba_using_speedangle  woba_value  woba_denom  babip_value  \
# 0                                NaN         0.0         NaN          0.0
# 1                                NaN         NaN         NaN          NaN
# 2                                NaN         NaN         NaN          NaN
# 3                                NaN         NaN         NaN          NaN
# 4                                NaN         0.0         NaN          0.0
# ..                               ...         ...         ...          ...
# 200                              NaN         NaN         NaN          NaN
# 201                              NaN         0.0         NaN          0.0
# 202                              NaN         NaN         NaN          NaN
# 203                              NaN         0.0         NaN          0.0
# 204                              NaN         NaN         NaN          NaN
#
#      iso_value  launch_speed_angle at_bat_number pitch_number  \
# 0          0.0                 NaN            51            4
# 1          NaN                 NaN            51            3
# 2          NaN                 NaN            51            2
# 3          NaN                 NaN            51            1
# 4          0.0                 NaN            69            2
# ..         ...                 ...           ...          ...
# 200        NaN                 NaN            10            1
# 201        0.0                 NaN            40            2
# 202        NaN                 NaN            40            1
# 203        0.0                 NaN            56            2
# 204        NaN                 NaN            56            1
#
#           pitch_name home_score away_score bat_score fld_score  \
# 0           Changeup          5          4         4         5
# 1             Sinker          5          4         4         5
# 2             Sinker          5          4         4         5
# 3             Sinker          5          4         4         5
# 4    4-Seam Fastball          2          3         3         2
# ..               ...        ...        ...       ...       ...
# 200  4-Seam Fastball          1          0         1         0
# 201              NaN          3          0         3         0
# 202         Changeup          3          0         3         0
# 203  4-Seam Fastball          3          1         3         1
# 204           Sinker          3          1         3         1
#
#     post_away_score post_home_score post_bat_score post_fld_score  \
# 0                 4               5              4              5
# 1                 4               5              4              5
# 2                 4               5              4              5
# 3                 4               5              4              5
# 4                 3               2              3              2
# ..              ...             ...            ...            ...
# 200               0               1              1              0
# 201               0               3              3              0
# 202               0               3              3              0
# 203               1               3              3              1
# 204               1               3              3              1
#
#      if_fielding_alignment  of_fielding_alignment  spin_axis  \
# 0                      NaN                    NaN        NaN
# 1                      NaN                    NaN        NaN
# 2                      NaN                    NaN        NaN
# 3                      NaN                    NaN        NaN
# 4                      NaN                    NaN        NaN
# ..                     ...                    ...        ...
# 200                    NaN                    NaN        NaN
# 201                    NaN                    NaN        NaN
# 202                    NaN                    NaN        NaN
# 203                    NaN                    NaN        NaN
# 204                    NaN                    NaN        NaN
#
#      delta_home_win_exp  delta_run_exp  bat_speed  swing_length
# 0                 0.046         -0.238        NaN           NaN
# 1                 0.000         -0.072        NaN           NaN
# 2                 0.000         -0.048        NaN           NaN
# 3                 0.000          0.042        NaN           NaN
# 4                 0.017         -0.264        NaN           NaN
# ..                  ...            ...        ...           ...
# 200               0.000         -0.141        NaN           NaN
# 201              -0.004         -0.089        NaN           NaN
# 202               0.000         -0.016        NaN           NaN
# 203              -0.006         -0.120        NaN           NaN
# 204               0.000          0.015        NaN           NaN
#
# [205 rows x 94 columns]
