# %%
# !pip install pybaseball > null

# %%
from pybaseball import get_splits
from pybaseball import playerid_lookup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
pd.set_option('display.max_columns', 500)
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]

# %%
# find Scott Hatteberg's player id (mlbam_key)
key_bbref = playerid_lookup('hatteberg', 'scott').loc[0, 'key_bbref']
active_years = []

# get all available date
career_total = get_splits(key_bbref)

# each year separated into it's table
# Out:
# C:\Users\marti\anaconda3\Lib\site-packages\pybaseball\split_stats.py:71: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   commentsoup = bs.BeautifulSoup(comment[i], 'lxml')

# %%
career_total
# Out:
#                                     G    GS    PA    AB     R     H   2B  3B  \
# Split Type     Split
# Season Totals  Career Totals     1314  1106  4876  4226   538  1153  249   7
# Platoon Splits vs RHP            1230  <NA>  3858  3344   443   945  206   6
#                vs LHP             587  <NA>  1018   882    95   208   43   1
#                vs RHP as LHB     1230  <NA>  3858  3344  <NA>   945  206   6
#                vs LHP as LHB      587  <NA>  1018   882  <NA>   208   43   1
# ...                               ...   ...   ...   ...   ...   ...  ...  ..
# Ballparks      TBD-TropicanaFld    39    36   159   138    24    38    5   1
#                ATL-Turner Fld      12    10    46    38     8     7    1   0
#                PHI-VeteransStad     5     4    18    15     3     3    3   0
#                CHC-Wrigley Fld     16    12    54    41     3     5    1   0
#                NYY-Yankee Stad     29    25   111    97    17    30    8   0
#
# ...
